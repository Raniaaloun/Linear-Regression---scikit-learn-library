# %%
import pandas as pd
data = pd.read_csv("../A1/Years_Salary.csv")
data.head(5)
# Out:
#    YearsExperience  Salary
# 0              1.1    4917
# 1              1.3    5775
# 2              1.5    4716
# 3              2.0    5440
# 4              2.2    4986

# %%
X = data.iloc[:, :-1].values
Y = data.iloc[:, -1].values

# %%
import matplotlib.pyplot as plt
plt.scatter(X,Y)
plt.title("Data")
plt.xlabel("years of experience")
plt.ylabel("salary")
classes = ["Data set"]
plt.legend(labels=classes)
plt.show()

# %%
from sklearn.model_selection import train_test_split 
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 1/3, random_state = 42)
m = X_train.size
Y_test = Y_test.reshape(X_test.size,1)
Y_train = Y_train.reshape(m,1)

# %%
plt.scatter(X_test, Y_test, marker = 'o', color = 'blue')
plt.scatter(X_train, Y_train, marker = '^', color = 'red')

plt.title("Splitted Data")
plt.xlabel("years of experience")
plt.ylabel("salary")

classes = ["Testing Data", "Training Data"]
plt.legend(labels=classes)

plt.show()

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression().fit(X_train, Y_train)
regressor.fit(X_train, Y_train)

print("value of 𝜃0 =", *regressor.intercept_ )
print("value of 𝜃1 =", *regressor.coef_)
print("ℎ𝜃(𝑥) =",*regressor.intercept_," +", *regressor.coef_,"* 𝑥")
#print(yhat)
# Out:
# value of 𝜃0 = 3164.9835576327496
# value of 𝜃1 = [1178.2801678]
# ℎ𝜃(𝑥) = 3164.9835576327496  + [1178.2801678] * 𝑥

# %%
#passing testing data
Y_predicit_test = regressor.predict(X_test)
Y_predicit_train = regressor.predict(X_train)

# %%
plt.scatter(X_train, Y_train, marker = 'o', color = 'blue')
plt.plot(X_train, Y_predicit_train, linewidth=2, color = 'red')
plt.title("Model with training data set")
plt.xlabel("years of experience")
plt.ylabel("salary")

classes = ["model", "training data"]
plt.legend(labels=classes)
plt.ylim(ymin=4000)

plt.show()

# %%
plt.scatter(X_train, Y_train, marker = 'o', color = 'blue')
plt.plot(X_test, Y_predicit_test, linewidth=2, color = 'red')

plt.title("Model with testing data set")
plt.xlabel("years of experience")
plt.ylabel("salary")

classes = ["model", "training data"]
plt.legend(labels=classes)
plt.ylim(ymin=4000)

plt.show()
